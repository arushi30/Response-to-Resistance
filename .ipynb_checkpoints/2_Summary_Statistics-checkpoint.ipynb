# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
combined = pd.read_csv("../Personal Response_to_Resistance/Input Data/clean_data.csv", header=0)
#combined = pd.read_csv('clean_data.csv')
combined.head()
# Out:
# /Users/brinaseidel/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              date_time      date_x    time              loc_t ype  zip_code  \
# 0  2014-10-01 20:19:00  10/01/2014  2019.0       RESIDENCE / HOME   78723.0
# 1  2014-10-05 16:33:00  10/05/2014  1633.0       RESIDENCE / HOME   78723.0
# 2  2012-01-20 22:30:00  01/20/2012  2230.0  PARKING LOTS / GARAGE   78723.0
# 3  2011-01-01 20:00:00  01/01/2011  2000.0       RESIDENCE / HOME   78723.0
# 4  2012-03-06 05:00:00  03/06/2012   500.0       RESIDENCE / HOME   78723.0
#
#    council_district apd_sector apd_district   latitude  longtitude  \
# 0               1.0         ID            1  30.315506  -97.690678
# 1               1.0         ID            1  30.315506  -97.690678
# ...

# %% [markdown]
# ## Map crime and resistance by census tract

# %%
# Get the incident count and resistence count by census tract
resistance_count = pd.DataFrame(combined.groupby("tract")['Target1'].sum()).reset_index()
crime_count = pd.DataFrame(combined.groupby("tract").size()).reset_index()

counts = pd.merge(resistance_count, crime_count, on="tract")
counts.columns = ["TRACT", "resistance_count", "crime_count"]

# %%
# Read in the 2010 shapefile for the relevant counties 
# Downloaded from https://www.census.gov/geo/maps-data/data/cbf/cbf_tracts.html
map_df = gpd.read_file("Input Data/gz_2010_48_140_00_500k.shp")
map_df = map_df.loc[(map_df["COUNTY"] == "453") | (map_df["COUNTY"] == "491"), ]

# %%
# Merge the shapefile with the crime data
map_df =pd.merge(map_df, counts, on="TRACT", how="outer", indicator=True)
map_df = map_df.loc[map_df["_merge"]!="left_only", ]

# %%
vmin, vmax = 0, 70000
fig, ax = plt.subplots(1, figsize=(10, 6))
map_df.plot(column="crime_counts", cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_counts'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-0d77b6ef413b> in <module>()
#       1 vmin, vmax = 0, 70000
# ...

# %%
vmin = 0
vmax = 80000
map_df.plot(column="crime_count", cmap='Blues', linewidth=0.8, edgecolor='0.8')

# %%
(map_df["COUNTY"] == "453") | (map_df["COUNTY"] == "491")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5229    False
# 5230    False
# 5231    False
# 5232    False
# 5233    False
# 5234    False
# 5235    False
# 5236    False
# 5237    False
# 5238    False
# 5239    False
# 5240    False
# 5241    False
# 5242    False
# 5243     True
# 5244     True
# 5245    False
# 5246    False
# 5247    False
# 5248    False
# 5249    False
# 5250    False
# 5251    False
# 5252    False
# 5253    False
# 5254    False
# 5255    False
# 5256     True
# 5257    False
# 5258    False
# ...

# %%
map_df.head()
# Out:
#                     GEO_ID STATE COUNTY   TRACT   NAME   LSAD  CENSUSAREA  \
# 926   1400000US48453002424    48    453  002424  24.24  Tract       1.069
# 927   1400000US48453002425    48    453  002425  24.25  Tract       0.752
# 928   1400000US48453002426    48    453  002426  24.26  Tract       5.427
# 929   1400000US48453002434    48    453  002434  24.34  Tract      21.298
# 1010  1400000US48453000203    48    453  000203   2.03  Tract       0.467
#
#                                                geometry
# 926   POLYGON ((-97.804423 30.185679, -97.809528 30....
# 927   POLYGON ((-97.78498399999999 30.167032, -97.78...
# 928   POLYGON ((-97.73470599999999 30.154016, -97.73...
# 929   POLYGON ((-97.690614 30.042456, -97.6913819999...
# 1010  POLYGON ((-97.73925799999999 30.30333, -97.743...

# %%
counts
# Out:
#       TRACT  resistance_count  crime_count
# 0    000101              16.0         2344
# 1    000102               5.0         1631
# 2    000203               7.0         9114
# 3    000204              50.0         4469
# 4    000205              22.0         3259
# 5    000206              14.0         2443
# 6    000302              47.0         7562
# 7    000304              49.0         5068
# 8    000305              17.0         3139
# 9    000306              53.0         6567
# 10   000307              31.0         3599
# 11   000401              49.0         4495
# 12   000402              36.0         3797
# 13   000500               9.0         3023
# 14   000601              10.0         2049
# 15   000603              55.0         8132
# 16   000604              48.0         6845
# 17   000700             150.0         6440
# 18   000801              47.0         3488
# 19   000802             102.0         7853
# 20   000803             228.0         8052
# ...
